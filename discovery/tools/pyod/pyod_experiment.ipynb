# %%
import os
import pandas as pd
import numpy as np
import time
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Data

# %%
if not os.path.exists('../../../data/players'):
    !7z x ../../../data/players.7z -o../../../data/

if not os.path.exists('../../../data/boxscoretraditionalv2'):
    !7z x ../../../data/season_21-22.7z -o../../../data/

# %%
dallas_id = teams.find_team_by_abbreviation('DAL')['id']
season_2122 = leaguegamefinder.LeagueGameFinder(team_id_nullable=dallas_id, season_nullable='2021-22', season_type_nullable=leaguegamefinder.SeasonTypeNullable.regular)
season = season_2122.get_data_frames()[0]
print(season.shape)
season.head()
# Out:
# (82, 28)
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  \
# 0     22021  1610612742               DAL  Dallas Mavericks  0022101219
# 1     22021  1610612742               DAL  Dallas Mavericks  0022101209
# 2     22021  1610612742               DAL  Dallas Mavericks  0022101190
# 3     22021  1610612742               DAL  Dallas Mavericks  0022101167
# 4     22021  1610612742               DAL  Dallas Mavericks  0022101152
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2022-04-10  DAL vs. SAS  W  240  130   46   85   0.541    20    36
# 1  2022-04-08  DAL vs. POR  W  241  128   42   79   0.532    20    45
# 2  2022-04-06    DAL @ DET  W  238  131   45   80   0.563    15    33
# 3  2022-04-03    DAL @ MIL  W  239  118   39   76   0.513    16    38
# 4  2022-04-01    DAL @ WAS  L  239  103   34   78   0.436    11    38
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.556   18   23   0.783    10    33   43   34    5    3   16  16
# 1    0.444   24   31   0.774     9    42   51   25    9    5   14  19
# 2    0.455   26   34   0.765     8    33   41   28    8    1   10  24
# 3    0.421   24   27   0.889     2    36   38   28    7    3   12  20
# 4    0.289   24   26   0.923     5    31   36   14    3    3   13  16
#
#    PLUS_MINUS
# 0        10.0
# 1        50.0
# 2        18.0
# 3         6.0
# 4       -32.0

# %%
object_dtypes = {col: object for col in ['GAME_ID', 'TEAM_ID', 'PLAYER_ID']}
df = (
    pd.concat([pd.read_csv(f'../../../data/boxscoretraditionalv2/boxscoretraditionalv2_0_{game_id}.csv', dtype=object_dtypes) 
               for game_id in season.GAME_ID.iloc[:]])
    .query('TEAM_ABBREVIATION == "DAL"')
    .dropna(subset=['MIN'])
)
df[['_min', '_sec']] = df['MIN'].str.split(':', expand=True)
df['min_sec'] = df._min.astype(float) + df._sec.astype(int) / 60 
print(df.shape)
df.head()
# Out:
# (917, 32)
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY PLAYER_ID  \
# 13  0022101219  1610612742               DAL    Dallas    203493
# 14  0022101219  1610612742               DAL    Dallas   1627827
# 15  0022101219  1610612742               DAL    Dallas    203939
# 16  0022101219  1610612742               DAL    Dallas   1628973
# 17  0022101219  1610612742               DAL    Dallas   1629029
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT           MIN  FGM  \
# 13       Reggie Bullock   Reggie              F     NaN  26.000000:37  1.0
# 14  Dorian Finney-Smith   Dorian              F     NaN  27.000000:15  6.0
# 15        Dwight Powell   Dwight              C     NaN  25.000000:05  5.0
# 16        Jalen Brunson    Jalen              G     NaN  24.000000:41  7.0
# 17          Luka Doncic     Luka              G     NaN  28.000000:45  8.0
#
#      FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# 13   6.0   0.167   1.0   3.0    0.333  1.0  1.0   1.000   1.0   2.0  3.0  2.0
# 14   7.0   0.857   4.0   5.0    0.800  0.0  0.0   0.000   0.0   3.0  3.0  1.0
# 15   6.0   0.833   0.0   0.0    0.000  2.0  6.0   0.333   3.0   4.0  7.0  2.0
# 16  13.0   0.538   3.0   7.0    0.429  1.0  2.0   0.500   0.0   6.0  6.0  5.0
# 17  18.0   0.444   2.0   5.0    0.400  8.0  8.0   1.000   1.0   7.0  8.0  9.0
#
#     STL  BLK   TO   PF   PTS  PLUS_MINUS       _min _sec    min_sec
# 13  0.0  0.0  1.0  3.0   4.0        16.0  26.000000   37  26.616667
# 14  1.0  0.0  0.0  0.0  16.0        14.0  27.000000   15  27.250000
# 15  0.0  1.0  3.0  2.0  12.0        11.0  25.000000   05  25.083333
# 16  0.0  0.0  1.0  0.0  18.0        12.0  24.000000   41  24.683333
# 17  2.0  1.0  4.0  1.0  26.0        19.0  28.000000   45  28.750000

# %%
df.to_csv('dallas_season_2021_22_boxscoretraditionalv2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917 entries, 13 to 12
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            917 non-null    object
#  1   TEAM_ID            917 non-null    object
#  2   TEAM_ABBREVIATION  917 non-null    object
#  3   TEAM_CITY          917 non-null    object
#  4   PLAYER_ID          917 non-null    object
#  5   PLAYER_NAME        917 non-null    object
#  6   NICKNAME           917 non-null    object
#  7   START_POSITION     410 non-null    object
#  8   COMMENT            0 non-null      object
#  9   MIN                917 non-null    object
#  10  FGM                917 non-null    float64
#  11  FGA                917 non-null    float64
#  12  FG_PCT             917 non-null    float64
#  13  FG3M               917 non-null    float64
#  14  FG3A               917 non-null    float64
#  15  FG3_PCT            917 non-null    float64
#  16  FTM                917 non-null    float64
#  17  FTA                917 non-null    float64
#  18  FT_PCT             917 non-null    float64
#  19  OREB               917 non-null    float64
#  20  DREB               917 non-null    float64
#  21  REB                917 non-null    float64
#  22  AST                917 non-null    float64
#  23  STL                917 non-null    float64
#  24  BLK                917 non-null    float64
#  25  TO                 917 non-null    float64
#  26  PF                 917 non-null    float64
#  27  PTS                917 non-null    float64
#  28  PLUS_MINUS         917 non-null    float64
#  29  _min               917 non-null    object
#  30  _sec               917 non-null    object
#  31  min_sec            917 non-null    float64
# dtypes: float64(20), object(12)
# memory usage: 236.4+ KB

# %%
COLS = ['min_sec', 'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA',
        'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS']

# %% [markdown]
# # IForest

# %%
from pyod.models.iforest import IForest, check_array
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from sklearn.preprocessing import StandardScaler

# %%
df_train = StandardScaler().fit_transform(df[COLS])
# df_train.info()
check_array(df_train)
CONTAMINATION = 0.1
clfs = [IForest(contamination=CONTAMINATION), OCSVM(contamination=CONTAMINATION), LOF(contamination=CONTAMINATION)]
preds = {}
cnts = {}
scores = {}
for clf in clfs:
    clf.fit(df_train)
    _key = str(clf).split('(')[0]
    _preds = clf.labels_  # binary labels (0: inliers, 1: outliers)
    preds[_key] = _preds
    scores[_key] = clf.decision_scores_  # raw outlier scores
    cnts[_key] = np.sum(_preds)
cnts
# Out:
# {'IForest': 92, 'OCSVM': 92, 'LOF': 92}

# %%
voted_preds = None
for _preds in preds.values():
    if voted_preds is None:
        voted_preds = _preds
    else:
        voted_preds = ((voted_preds == 1) & (_preds == 1)).astype(int)
    
np.sum(voted_preds)
# Out:
# 8

# %%
df_rep = df.loc[voted_preds == 1].copy()
game_id_to_date = season.set_index('GAME_ID').GAME_DATE.to_dict()
df_rep['GAME_DATE'] = df_rep.GAME_ID.map(game_id_to_date)
df_rep
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY PLAYER_ID  \
# 4   0022101059  1610612742               DAL    Dallas   1629029
# 5   0022101014  1610612742               DAL    Dallas   1628467
# 6   0022100868  1610612742               DAL    Dallas   1628467
# 17  0022100778  1610612742               DAL    Dallas   1628973
# 15  0022100705  1610612742               DAL    Dallas    204001
# 15  0022100663  1610612742               DAL    Dallas   1629029
# 13  0022100410  1610612742               DAL    Dallas    204001
# 17  0022100069  1610612742               DAL    Dallas   1628467
#
#            PLAYER_NAME  NICKNAME START_POSITION COMMENT           MIN   FGM  \
# 4          Luka Doncic      Luka              G     NaN  29.000000:52  13.0
# 5          Maxi Kleber      Maxi            NaN     NaN  28.000000:49   0.0
# 6          Maxi Kleber      Maxi            NaN     NaN  34.000000:55   5.0
# 17       Jalen Brunson     Jalen              G     NaN  42.000000:33  10.0
# 15  Kristaps Porzingis  Kristaps              C     NaN  25.000000:36   6.0
# 15         Luka Doncic      Luka              G     NaN  38.000000:40   4.0
# 13  Kristaps Porzingis  Kristaps              F     NaN  25.000000:17   7.0
# 17         Maxi Kleber      Maxi            NaN     NaN  29.000000:18   4.0
#
#      FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB  \
# 4   20.0   0.650   8.0  12.0    0.667   3.0   5.0   0.600   0.0   4.0   4.0
# 5    2.0   0.000   0.0   1.0    0.000   0.0   0.0   0.000   1.0  12.0  13.0
# 6   10.0   0.500   3.0   8.0    0.375   6.0   8.0   0.750   2.0   4.0   6.0
# 17  18.0   0.556   0.0   4.0    0.000   0.0   0.0   0.000   0.0   5.0   5.0
# 15  11.0   0.545   2.0   7.0    0.286   1.0   3.0   0.333   1.0   7.0   8.0
# 15  17.0   0.235   0.0   6.0    0.000  12.0  14.0   0.857   2.0   9.0  11.0
# 13  16.0   0.438   3.0   8.0    0.375   7.0   9.0   0.778   4.0   9.0  13.0
# 17   8.0   0.500   4.0   8.0    0.500   0.0   0.0   0.000   3.0   7.0  10.0
#
#      AST  STL  BLK   TO   PF   PTS  PLUS_MINUS       _min _sec    min_sec  \
# 4    3.0  0.0  0.0  4.0  2.0  37.0       -30.0  29.000000   52  29.866667
# 5    0.0  0.0  3.0  1.0  3.0   0.0         7.0  28.000000   49  28.816667
# 6    0.0  1.0  5.0  1.0  3.0  19.0        13.0  34.000000   55  34.916667
# 17   4.0  2.0  0.0  6.0  5.0  20.0         3.0  42.000000   33  42.550000
# 15   2.0  0.0  6.0  0.0  6.0  15.0        15.0  25.000000   36  25.600000
# 15  12.0  3.0  3.0  2.0  2.0  20.0        12.0  38.000000   40  38.666667
# 13   0.0  0.0  5.0  0.0  2.0  24.0        12.0  25.000000   17  25.283333
# 17   2.0  1.0  6.0  0.0  5.0  12.0        22.0  29.000000   18  29.300000
#
#      GAME_DATE
# 4   2022-03-19
# 5   2022-03-13
# 6   2022-02-15
# 17  2022-02-02
# 15  2022-01-23
# 15  2022-01-17
# 13  2021-12-13
# 17  2021-10-28

# %%
df_rep.to_csv('predicted_anomalies.csv')
