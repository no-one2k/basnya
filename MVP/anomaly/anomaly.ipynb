# %%
import os
from typing import List
from pprint import pprint

import pandas as pd
import numpy as np
import sqlite3
from pyod.models.iforest import IForest, check_array
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from sklearn.ensemble import IsolationForest
import shap


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# # Utils

# %%
SEED = 42

def cast_to_0_1(preds):
    """
    from  -1 for outlies and 1 for inliers
    to 0 for inliers and 1 for outliers)
    """
    return (preds == -1).astype(int)

def explain_outlier(shap_value, columns, top_k=5):
    """
    Get TOP abnormal features
    """
    _vals = shap_value.values
    top_5 = np.argsort(_vals)[:top_k]
    return ({columns[idx]: _vals[idx] for idx in top_5})

# %% [markdown]
# # Get  Data

# %%
class  AnomalyСalculation:
    '''
    Рассчёт аномалий по прошедшим играм
    '''
    
    def __init__(self):
        # для рассчёта аномалий
        self.calculus_col = ['min_sec', 'FGM', 'FGA', 'FG3M', 'FG3A', 'FTM', 'FTA', 
                             'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS']
        
        # для доп контекста
        self.labels_col =  ['GAME_ID', 'TEAM_ID',	'TEAM_ABBREVIATION',	
                            'TEAM_CITY',	'PLAYER_ID',	'PLAYER_NAME',	'NICKNAME']
    
    
    def get_data(self, limit=10000000000, db_path: str=r'../../data/basnya.db'):
        """
        Получить данные из локаьной SQLite
        
        Аргументы:
            db_path - путь до локальной БД
            limit - указывает, солько последних записей взять
        Возвращает:
            df - данные из бд в формате DataFrame
        """

        conn = sqlite3.connect(db_path)
        
        game2date = (
            pd.read_sql_query("SELECT * FROM GAMES", conn)
            .set_index('GAME_ID')['GAME_DATE_EST']
            ).to_dict()
        
        df = (
            pd.read_sql_query(f"SELECT * FROM boxscoretraditionalv2_0 LIMIT {limit}", conn)
            .drop('index', axis=1)
        )
        df[['_min', '_sec']] = df['MIN'].str.split(':', expand=True).fillna(0)
        df['min_sec'] = df._min.astype(float) + df._sec.astype(int) / 60 
        df['GAME_DATE'] = pd.to_datetime(df['GAME_ID'].map(game2date)).fillna(pd.to_datetime('1900-01-01'))
        return df.fillna(0)
    
    def get_anomalous_records(self, date: str) -> pd.DataFrame:
        """
        Получить аномальные значения
        
        Аргументы:
            date - дата (пример: 2021-11-10), ДО которой будет обучаться IF для того, чтоб определить аномалию для игр ПОСЛЕ date
        
        Возвращает: DataFrame с аномальными значениями
        """
        
        df = self.get_data()
        
        if date == None:
            df_train, df_test, _, _= train_test_split(df, df, test_size=0.2, random_state=SEED)


        df_train = df.loc[df['GAME_DATE'] <= pd.to_datetime(date)]
        df_test = df.loc[df['GAME_DATE'] > pd.to_datetime(date)]
        
        scaler = StandardScaler()
        
        X_train = scaler.fit_transform(df_train[self.calculus_col])
        X_test = scaler.transform(df_test[self.calculus_col])
        
        # create and fit IsolationForest model
        CONTAMINATION = 0.01
        clf =  IsolationForest(contamination=CONTAMINATION, random_state=SEED)
        clf.fit(X_train)
        _preds = cast_to_0_1(clf.predict(X_test)) # if anomaly:1 else:0
        
        # explanation of anomalies for isolation forest
        explainer = shap.TreeExplainer(clf, feature_names=self.calculus_col)
        # get shape_values for each example X_test 
        shap_values = explainer(X_test) 
        
        anomaly_with_shape = []
        
        for example, (_, context) in zip(shap_values[_preds==1][:10], df_test[_preds==1][self.labels_col][:10].iterrows()):
            anomaly_with_shape.append({'shape_value': explain_outlier(example, columns=self.calculus_col),
                                       'context': context.to_dict()})
           
        return anomaly_with_shape

# %%
# ------------------- TESTING -------------------------------
anomaly = AnomalyСalculation()
anomaly_records = anomaly.get_anomalous_records('2021-10-10')
anomaly_records
# Out:
# [{'shape_value': {'FG3M': -1.2603159403805317,
#    'FG3A': -1.2392756779069771,
#    'FGA': -0.8698809703459265,
#    'FGM': -0.7540991175091406,
#    'PTS': -0.7273360235039464},
#   'context': {'GAME_ID': 12100057,
#    'TEAM_ID': 1610612743,
#    'TEAM_ABBREVIATION': 'DEN',
#    'TEAM_CITY': 'Denver',
#    'PLAYER_ID': 1630210,
#    'PLAYER_NAME': 'Markus Howard',
#    'NICKNAME': 'Markus'}},
#  {'shape_value': {'FG3M': -1.0183068931302433,
#    'FG3A': -0.8316612084503043,
#    'PTS': -0.7513910825956549,
#    'FGM': -0.6424492650283425,
#    'FGA': -0.560458106046341},
#   'context': {'GAME_ID': 12100066,
#    'TEAM_ID': 1610612744,
#    'TEAM_ABBREVIATION': 'GSW',
#    'TEAM_CITY': 'Golden State',
#    'PLAYER_ID': 201939,
#    'PLAYER_NAME': 'Stephen Curry',
#    'NICKNAME': 'Stephen'}},
#  {'shape_value': {'BLK': -1.6297115780368925,
#    'FTA': -0.9235368574167693,
#    'STL': -0.8826940032221455,
#    'FTM': -0.739388425227038,
#    'min_sec': -0.56178943550655},
#   'context': {'GAME_ID': 22100005,
#    'TEAM_ID': 1610612738,
#    'TEAM_ABBREVIATION': 'BOS',
#    'TEAM_CITY': 'Boston',
#    'PLAYER_ID': 1629057,
#    'PLAYER_NAME': 'Robert Williams III',
#    'NICKNAME': 'Robert'}},
#  {'shape_value': {'FG3M': -0.8463469092531447,
#    'FG3A': -0.7677589689297922,
#    'FGA': -0.7186186304830892,
#    'PTS': -0.6618821296345767,
#    'STL': -0.6589226759616778},
#   'context': {'GAME_ID': 22100005,
#    'TEAM_ID': 1610612738,
#    'TEAM_ABBREVIATION': 'BOS',
#    'TEAM_CITY': 'Boston',
#    'PLAYER_ID': 1627759,
#    'PLAYER_NAME': 'Jaylen Brown',
#    'NICKNAME': 'Jaylen'}},
#  {'shape_value': {'TO': -0.9097560848373123,
#    'BLK': -0.7475113106248705,
#    'AST': -0.7026448131620812,
#    'FGA': -0.652456765614274,
#    'FTM': -0.5597121684257704},
#   'context': {'GAME_ID': 22100005,
#    'TEAM_ID': 1610612752,
#    'TEAM_ABBREVIATION': 'NYK',
#    'TEAM_CITY': 'New York',
#    'PLAYER_ID': 203944,
#    'PLAYER_NAME': 'Julius Randle',
#    'NICKNAME': 'Julius'}},
#  {'shape_value': {'STL': -1.2848720879238154,
#    'FG3A': -0.984719049954354,
#    'FG3M': -0.9264182076567896,
#    'FGM': -0.744959241662056,
#    'FGA': -0.6909814197671675},
#   'context': {'GAME_ID': 22100005,
#    'TEAM_ID': 1610612752,
#    'TEAM_ABBREVIATION': 'NYK',
#    'TEAM_CITY': 'New York',
#    'PLAYER_ID': 203095,
#    'PLAYER_NAME': 'Evan Fournier',
#    'NICKNAME': 'Evan'}},
#  {'shape_value': {'FG3M': -1.1001076146766708,
#    'PTS': -0.7795353425348809,
#    'FTA': -0.6764689479814165,
#    'FG3A': -0.6734731062050187,
#    'FTM': -0.6111481092617076},
#   'context': {'GAME_ID': 22100013,
#    'TEAM_ID': 1610612758,
#    'TEAM_ABBREVIATION': 'SAC',
#    'TEAM_CITY': 'Sacramento',
#    'PLAYER_ID': 203084,
#    'PLAYER_NAME': 'Harrison Barnes',
#    'NICKNAME': 'Harrison'}},
#  {'shape_value': {'FG3M': -0.9318005644088209,
#    'STL': -0.7783357290022527,
#    'FGM': -0.7730003374978863,
#    'TO': -0.7073533289630425,
#    'PTS': -0.6879668635107655},
#   'context': {'GAME_ID': 22100013,
#    'TEAM_ID': 1610612757,
#    'TEAM_ABBREVIATION': 'POR',
#    'TEAM_CITY': 'Portland',
#    'PLAYER_ID': 203468,
#    'PLAYER_NAME': 'CJ McCollum',
#    'NICKNAME': 'CJ'}},
#  {'shape_value': {'FG3M': -1.0939621593191495,
#    'FG3A': -0.8788368186732564,
#    'TO': -0.8239712119600067,
#    'PTS': -0.8020634477274312,
#    'FGA': -0.6857830668278436},
#   'context': {'GAME_ID': 22100016,
#    'TEAM_ID': 1610612744,
#    'TEAM_ABBREVIATION': 'GSW',
#    'TEAM_CITY': 'Golden State',
#    'PLAYER_ID': 201939,
#    'PLAYER_NAME': 'Stephen Curry',
#    'NICKNAME': 'Stephen'}},
#  {'shape_value': {'BLK': -0.7480375925150534,
#    'FG3M': -0.7455099132222096,
#    'PTS': -0.7058945091299264,
#    'FGM': -0.6944967665466946,
#    'FTA': -0.5945046183343511},
#   'context': {'GAME_ID': 22100019,
#    'TEAM_ID': 1610612754,
#    'TEAM_ABBREVIATION': 'IND',
#    'TEAM_CITY': 'Indiana',
#    'PLAYER_ID': 1626167,
#    'PLAYER_NAME': 'Myles Turner',
#    'NICKNAME': 'Myles'}}]

# %%
pprint(anomaly_records )
# Out:
# [{'context': {'GAME_ID': 12100057,
#               'NICKNAME': 'Markus',
#               'PLAYER_ID': 1630210,
#               'PLAYER_NAME': 'Markus Howard',
#               'TEAM_ABBREVIATION': 'DEN',
#               'TEAM_CITY': 'Denver',
#               'TEAM_ID': 1610612743},
#   'shape_value': {'FG3A': -1.2392756779069771,
#                   'FG3M': -1.2603159403805317,
#                   'FGA': -0.8698809703459265,
#                   'FGM': -0.7540991175091406,
#                   'PTS': -0.7273360235039464}},
#  {'context': {'GAME_ID': 12100066,
#               'NICKNAME': 'Stephen',
#               'PLAYER_ID': 201939,
#               'PLAYER_NAME': 'Stephen Curry',
#               'TEAM_ABBREVIATION': 'GSW',
#               'TEAM_CITY': 'Golden State',
#               'TEAM_ID': 1610612744},
#   'shape_value': {'FG3A': -0.8316612084503043,
#                   'FG3M': -1.0183068931302433,
#                   'FGA': -0.560458106046341,
#                   'FGM': -0.6424492650283425,
#                   'PTS': -0.7513910825956549}},
#  {'context': {'GAME_ID': 22100005,
#               'NICKNAME': 'Robert',
#               'PLAYER_ID': 1629057,
#               'PLAYER_NAME': 'Robert Williams III',
#               'TEAM_ABBREVIATION': 'BOS',
#               'TEAM_CITY': 'Boston',
#               'TEAM_ID': 1610612738},
#   'shape_value': {'BLK': -1.6297115780368925,
#                   'FTA': -0.9235368574167693,
#                   'FTM': -0.739388425227038,
#                   'STL': -0.8826940032221455,
#                   'min_sec': -0.56178943550655}},
#  {'context': {'GAME_ID': 22100005,
#               'NICKNAME': 'Jaylen',
#               'PLAYER_ID': 1627759,
#               'PLAYER_NAME': 'Jaylen Brown',
#               'TEAM_ABBREVIATION': 'BOS',
#               'TEAM_CITY': 'Boston',
#               'TEAM_ID': 1610612738},
#   'shape_value': {'FG3A': -0.7677589689297922,
#                   'FG3M': -0.8463469092531447,
#                   'FGA': -0.7186186304830892,
#                   'PTS': -0.6618821296345767,
#                   'STL': -0.6589226759616778}},
#  {'context': {'GAME_ID': 22100005,
#               'NICKNAME': 'Julius',
#               'PLAYER_ID': 203944,
#               'PLAYER_NAME': 'Julius Randle',
#               'TEAM_ABBREVIATION': 'NYK',
#               'TEAM_CITY': 'New York',
#               'TEAM_ID': 1610612752},
#   'shape_value': {'AST': -0.7026448131620812,
#                   'BLK': -0.7475113106248705,
#                   'FGA': -0.652456765614274,
#                   'FTM': -0.5597121684257704,
#                   'TO': -0.9097560848373123}},
#  {'context': {'GAME_ID': 22100005,
#               'NICKNAME': 'Evan',
#               'PLAYER_ID': 203095,
#               'PLAYER_NAME': 'Evan Fournier',
#               'TEAM_ABBREVIATION': 'NYK',
#               'TEAM_CITY': 'New York',
#               'TEAM_ID': 1610612752},
#   'shape_value': {'FG3A': -0.984719049954354,
#                   'FG3M': -0.9264182076567896,
#                   'FGA': -0.6909814197671675,
#                   'FGM': -0.744959241662056,
#                   'STL': -1.2848720879238154}},
#  {'context': {'GAME_ID': 22100013,
#               'NICKNAME': 'Harrison',
#               'PLAYER_ID': 203084,
#               'PLAYER_NAME': 'Harrison Barnes',
#               'TEAM_ABBREVIATION': 'SAC',
#               'TEAM_CITY': 'Sacramento',
#               'TEAM_ID': 1610612758},
#   'shape_value': {'FG3A': -0.6734731062050187,
#                   'FG3M': -1.1001076146766708,
#                   'FTA': -0.6764689479814165,
#                   'FTM': -0.6111481092617076,
#                   'PTS': -0.7795353425348809}},
#  {'context': {'GAME_ID': 22100013,
#               'NICKNAME': 'CJ',
#               'PLAYER_ID': 203468,
#               'PLAYER_NAME': 'CJ McCollum',
#               'TEAM_ABBREVIATION': 'POR',
#               'TEAM_CITY': 'Portland',
#               'TEAM_ID': 1610612757},
#   'shape_value': {'FG3M': -0.9318005644088209,
#                   'FGM': -0.7730003374978863,
#                   'PTS': -0.6879668635107655,
#                   'STL': -0.7783357290022527,
#                   'TO': -0.7073533289630425}},
#  {'context': {'GAME_ID': 22100016,
#               'NICKNAME': 'Stephen',
#               'PLAYER_ID': 201939,
#               'PLAYER_NAME': 'Stephen Curry',
#               'TEAM_ABBREVIATION': 'GSW',
#               'TEAM_CITY': 'Golden State',
#               'TEAM_ID': 1610612744},
#   'shape_value': {'FG3A': -0.8788368186732564,
#                   'FG3M': -1.0939621593191495,
#                   'FGA': -0.6857830668278436,
#                   'PTS': -0.8020634477274312,
#                   'TO': -0.8239712119600067}},
#  {'context': {'GAME_ID': 22100019,
#               'NICKNAME': 'Myles',
#               'PLAYER_ID': 1626167,
#               'PLAYER_NAME': 'Myles Turner',
#               'TEAM_ABBREVIATION': 'IND',
#               'TEAM_CITY': 'Indiana',
#               'TEAM_ID': 1610612754},
#   'shape_value': {'BLK': -0.7480375925150534,
#                   'FG3M': -0.7455099132222096,
#                   'FGM': -0.6944967665466946,
#                   'FTA': -0.5945046183343511,
#                   'PTS': -0.7058945091299264}}]
